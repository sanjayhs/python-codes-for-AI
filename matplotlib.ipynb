# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
x = [1,2,3,4]
y = [5,6,7,8]
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
plt.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y);
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
x = [10,20,30,40]
y = [100,200,300,400]
fig, ax = plt.subplots(figsize=(12,12))
ax.plot(x,y)
ax.set(title="my first graph",
xlabel="x axis",
ylabel="y axis")
plt.show()
